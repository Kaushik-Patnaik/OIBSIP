# %% [markdown]
# # Importing different libraries of python for the exploration of the data.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # ABOUT DATASET

# %% [markdown]
# This data set consists of three types of entities: (a) the specification of an auto in terms of various characteristics, (b) its
#
# assigned insurance risk rating, (c) its normalized losses in use as compared to other cars.  The second rating corresponds to
#
# the degree to which the auto is more risky than its price indicates. Cars are initially assigned a risk factor symbol associated
#
# with its price.   Then, if it is more risky (or less), this symbol is adjusted by moving it up (or down) the scale.  Actuarians
#
# call this process "symboling".  A value of +3 indicates that the auto is risky, -3 that it is probably pretty safe.
#
#
# The third factor is the relative average loss payment per insured vehicle year.  This value is normalized for all autos within a
#
# particular size classification (two-door small, station wagons, sports/speciality, etc...), and represents the average loss per
#
# car per year.

# %% [markdown]
# # Content

# %% [markdown]
# Attribute: Attribute Range
#
#   1.symboling:                -3, -2, -1, 0, 1, 2, 3.
#
#   2.make:
#                                alfa-romero, audi, bmw, chevrolet, dodge, honda,
#                                isuzu, jaguar, mazda, mercedes-benz, mercury,
#                                mitsubishi, nissan, peugot, plymouth, porsche,
#                                renault, saab, subaru, toyota, volkswagen, volvo
#
#   3.fuel-type:                diesel, gas.
#
#   4.aspiration:               std, turbo.
#
#   5.num-of-doors:             four, two.
#
#   6.body-style:               hardtop, wagon, sedan, hatchback, convertible.
#
#   7.drive-wheels:             4wd, fwd, rwd.
#
#   8.engine-location:          front, rear.
#
#   9.heel-base:               continuous from 86.6 120.9.
#
#  10.length:                   continuous from 141.1 to 208.1.
#
#  11.width:                    continuous from 60.3 to 72.3.
#
#  12.height:                   continuous from 47.8 to 59.8.
#
#  13 curb-weight:              continuous from 1488 to 4066.
#
#  14.engine-type:              dohc, dohcv, l, ohc, ohcf, ohcv, rotor.
#
#  15.num-of-cylinders:         eight, five, four, six, three, twelve, two.
#
#  16.engine-size:              continuous from 61 to 326.
#
#  17.fuel-system:              1bbl, 2bbl, 4bbl, idi, mfi, mpfi, spdi, spfi.
#
#  18.bore:                     continuous from 2.54 to 3.94.
#
#  19.roke:                   continuous from 2.07 to 4.17.
#
#  20.compression-ratio:        continuous from 7 to 23.
#
#  21.horsepower:               continuous from 48 to 288.
#
#  22.peak-rpm:                 continuous from 4150 to 6600.
#
#  23.city-mpg:                 continuous from 13 to 49.
#
#  24.highway-mpg:              continuous from 16 to 54.
#
#  25. price:                    continuous from 5118 to 454006

# %% [markdown]
# # Loading the data for analysis using pandas library

# %%
data=pd.read_csv(r"C:\Users\KAUSHIK\OneDrive\Desktop\DataScience Fullstack\CarPrice_Assignment.csv")

# %%
data.head(10)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
# 5       6          2                  audi fox      gas        std        two
# 6       7          1                audi 100ls      gas        std       four
# 7       8          1                 audi 5000      gas        std       four
# 8       9          1                 audi 4000      gas      turbo       four
# 9      10          0       audi 5000s (diesel)      gas      turbo        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# ...

# %%
data.shape
# Out:
# (205, 26)

# %%
data.size
# Out:
# 5330

# %% [markdown]
# # DATA CLEANING

# %%
data.isnull()
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0     False      False    False     False       False       False    False
# 1     False      False    False     False       False       False    False
# 2     False      False    False     False       False       False    False
# 3     False      False    False     False       False       False    False
# 4     False      False    False     False       False       False    False
# ..      ...        ...      ...       ...         ...         ...      ...
# 200   False      False    False     False       False       False    False
# 201   False      False    False     False       False       False    False
# 202   False      False    False     False       False       False    False
# 203   False      False    False     False       False       False    False
# 204   False      False    False     False       False       False    False
#
# ...

# %%
data.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
data.nunique()
# Out:
# car_ID              205
# symboling             6
# CarName             147
# fueltype              2
# aspiration            2
# doornumber            2
# carbody               5
# drivewheel            3
# enginelocation        2
# wheelbase            53
# carlength            75
# carwidth             44
# carheight            49
# curbweight          171
# enginetype            7
# cylindernumber        7
# enginesize           44
# fuelsystem            8
# boreratio            38
# stroke               37
# compressionratio     32
# horsepower           59
# peakrpm              23
# citympg              29
# highwaympg           30
# price               189
# dtype: int64

# %%
data.describe(include='all')
# Out:
#             car_ID   symboling        CarName fueltype aspiration doornumber  \
# count   205.000000  205.000000            205      205        205        205
# unique         NaN         NaN            147        2          2          2
# top            NaN         NaN  toyota corona      gas        std       four
# freq           NaN         NaN              6      185        168        115
# mean    103.000000    0.834146            NaN      NaN        NaN        NaN
# std      59.322565    1.245307            NaN      NaN        NaN        NaN
# min       1.000000   -2.000000            NaN      NaN        NaN        NaN
# 25%      52.000000    0.000000            NaN      NaN        NaN        NaN
# 50%     103.000000    1.000000            NaN      NaN        NaN        NaN
# 75%     154.000000    2.000000            NaN      NaN        NaN        NaN
# max     205.000000    3.000000            NaN      NaN        NaN        NaN
#
# ...

# %%
data.drop(['car_ID'] , axis=1, inplace=True)

# %%
data.head(10)
# Out:
#    symboling                   CarName fueltype aspiration doornumber  \
# 0          3        alfa-romero giulia      gas        std        two
# 1          3       alfa-romero stelvio      gas        std        two
# 2          1  alfa-romero Quadrifoglio      gas        std        two
# 3          2               audi 100 ls      gas        std       four
# 4          2                audi 100ls      gas        std       four
# 5          2                  audi fox      gas        std        two
# 6          1                audi 100ls      gas        std       four
# 7          1                 audi 5000      gas        std       four
# 8          1                 audi 4000      gas      turbo       four
# 9          0       audi 5000s (diesel)      gas      turbo        two
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0  convertible        rwd          front       88.6      168.8  ...
# ...

# %% [markdown]
# # Lets get the Categorical columns and Numerical columns

# %%
numerical_cols = []
categorical_cols = []

def get_numerical_and_categorical_columns(data):
    for column in data.columns:
        if pd.api.types.is_numeric_dtype(data[column]):
            numerical_cols.append(column)
        else:
            categorical_cols.append(column)

# %%
get_numerical_and_categorical_columns(data)

# %%
numerical_cols
# Out:
# ['symboling',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg',
#  'price']

# %%
categorical_cols
# Out:
# ['CarName',
#  'fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'enginetype',
#  'cylindernumber',
#  'fuelsystem']

# %% [markdown]
# # EDA ON CAR PRICE PREDICTION DATASET

# %%
corr_data=data.corr()
corr_data
# Out:
#                   symboling  wheelbase  carlength  carwidth  carheight  \
# symboling          1.000000  -0.531954  -0.357612 -0.232919  -0.541038
# wheelbase         -0.531954   1.000000   0.874587  0.795144   0.589435
# carlength         -0.357612   0.874587   1.000000  0.841118   0.491029
# carwidth          -0.232919   0.795144   0.841118  1.000000   0.279210
# carheight         -0.541038   0.589435   0.491029  0.279210   1.000000
# curbweight        -0.227691   0.776386   0.877728  0.867032   0.295572
# enginesize        -0.105790   0.569329   0.683360  0.735433   0.067149
# boreratio         -0.130051   0.488750   0.606454  0.559150   0.171071
# stroke            -0.008735   0.160959   0.129533  0.182942  -0.055307
# compressionratio  -0.178515   0.249786   0.158414  0.181129   0.261214
# horsepower         0.070873   0.353294   0.552623  0.640732  -0.108802
# peakrpm            0.273606  -0.360469  -0.287242 -0.220012  -0.320411
# ...

# %% [markdown]
# # Correlation Map

# %%
corrmap=corr_data.round(3)
plt.figure(figsize=(12,10))
sns.heatmap(corrmap,linewidth=2,linecolor='black',annot=True)
plt.show()

# %% [markdown]
# # Convert the categorical values into numerical values using Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder,MinMaxScaler

# %%
data2= data

# %%
data2.head(10)
# Out:
#    symboling                   CarName fueltype aspiration doornumber  \
# 0          3        alfa-romero giulia      gas        std        two
# 1          3       alfa-romero stelvio      gas        std        two
# 2          1  alfa-romero Quadrifoglio      gas        std        two
# 3          2               audi 100 ls      gas        std       four
# 4          2                audi 100ls      gas        std       four
# 5          2                  audi fox      gas        std        two
# 6          1                audi 100ls      gas        std       four
# 7          1                 audi 5000      gas        std       four
# 8          1                 audi 4000      gas      turbo       four
# 9          0       audi 5000s (diesel)      gas      turbo        two
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0  convertible        rwd          front       88.6      168.8  ...
# ...

# %%
le= LabelEncoder()
data2["CarName"]=le.fit_transform(data2["CarName"])
data2["fueltype"]=le.fit_transform(data2["fueltype"])
data2["aspiration"]=le.fit_transform(data2["aspiration"])
data2["doornumber"]=le.fit_transform(data2["doornumber"])
data2["carbody"]=le.fit_transform(data2["carbody"])
data2["drivewheel"]=le.fit_transform(data2["drivewheel"])
data2["enginelocation"]=le.fit_transform(data2["enginelocation"])
data2["enginetype"]=le.fit_transform(data2["enginetype"])
data2["cylindernumber"]=le.fit_transform(data2["cylindernumber"])
data2["fuelsystem"]=le.fit_transform(data2["fuelsystem"])

# %% [markdown]
# # Univariate Analysis

# %%
plt.figure(figsize=(12,10))
sns.histplot(data2["wheelbase"], kde=True,color='purple')
plt.title("wheelbase", fontsize=14)
plt.xlabel("Wheelbase")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.kdeplot(data=data2, x="symboling", hue=None, multiple="stack")
plt.title("Symboling", fontsize=14)
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.kdeplot(data=data2, x="carlength", hue=None, multiple="stack",color='green')
plt.title("Carlength", fontsize=14)
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.histplot(data2["carwidth"], kde=True,color='red')
plt.title("carwidth", fontsize=14)
plt.xlabel("Carwidth")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.histplot(data2["curbweight"], kde=True,color='blue')
plt.title("curbweight", fontsize=14)
plt.xlabel("curbweight")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.kdeplot(data=data2, x="enginesize", hue=None, multiple="stack",color='maroon')
plt.title("Enginesize", fontsize=14)
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.kdeplot(data=data2, x="boreratio", hue=None, multiple="stack",color='brown')
plt.title("boreratio", fontsize=14)
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.histplot(data2["stroke"], kde=True,color='orange')
plt.title("stroke", fontsize=14)
plt.xlabel("stroke")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.kdeplot(data=data2, x="compressionratio", hue=None, multiple="stack",color='lightgreen')
plt.title("compressionratio", fontsize=14)
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.kdeplot(data=data2, x="horsepower", hue=None,color='magenta')
plt.title("horsepower", fontsize=14)
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.kdeplot(data=data2, x="peakrpm", hue=None)
plt.title("peakrpm", fontsize=14)
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.kdeplot(data=data2, x="citympg", hue=None, multiple="stack",color='cyan')
plt.title("citympg", fontsize=14)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.kdeplot(data=data2, x="highwaympg", hue=None, multiple="stack",color='violet')
plt.title("highwaympg", fontsize=14)
plt.show()

# %%
plt.figure(figsize=(12,8))
data2["fueltype"].value_counts().plot(kind="bar", figsize=(6,4), rot=0 ,color='Plum')
plt.title("fueltype", fontsize=14)
plt.xlabel("fueltype")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(12,8))
data2["aspiration"].value_counts().plot(kind="bar", rot=0 ,color='Turquoise')
plt.title("aspiration", fontsize=14)
plt.xlabel("aspiration")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(12,8))
data2["doornumber"].value_counts().plot(kind="bar", rot=0 ,color='MidnightBlue')
plt.title("doornumber", fontsize=14)
plt.xlabel("doornumber")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(12,8))
data2["carbody"].value_counts().plot(kind="bar", rot=0 ,color='Coral')
plt.title("carbody", fontsize=14)
plt.xlabel("carbody")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(12,8))
data2["drivewheel"].value_counts().plot(kind="bar", rot=0 ,color='Teal')
plt.title("drivewheel", fontsize=14)
plt.xlabel("drivewheel")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(12,8))
data2["enginelocation"].value_counts().plot(kind="bar", rot=0 ,color='DarkMagenta')
plt.title("enginelocation", fontsize=14)
plt.xlabel("enginelocation")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(12,8))
data2["enginetype"].value_counts().plot(kind="bar", rot=0 ,color='Gold')
plt.title("enginetype", fontsize=14)
plt.xlabel("enginetype")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(12,8))
data2["cylindernumber"].value_counts().plot(kind="bar", rot=0 ,color='DeepSkyBlue')
plt.title("cylindernumber", fontsize=14)
plt.xlabel("cylindernumber")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(12,8)) 
data2["fuelsystem"].value_counts().plot(kind="bar", rot=0 ,color='SpringGreen')
plt.title("fuelsystem", fontsize=14)
plt.xlabel("fuelsystem")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Bivaraite Analysis

# %%
fig=plt.figure(figsize=(20,20)) #To visuaize the outliers we have used boxplots .

ax=fig.add_subplot(331)
sns.boxplot(data=data2, x=data2["fueltype"], y=data2["price"], hue=None ,color='Aqua',ax=ax)
ax.set_title('fueltype vs price', fontsize=16)

ax=fig.add_subplot(332)
sns.boxplot(data=data2, x=data2["aspiration"], y=data2["price"], hue=None ,color='Crimson',ax=ax)
ax.set_title('aspiration vs price', fontsize=16)

ax=fig.add_subplot(333)
sns.boxplot(data=data2, x=data2["doornumber"], y=data2["price"], hue=None ,color='Fuchsia',ax=ax)
ax.set_title('doornumber vs price', fontsize=16)

ax=fig.add_subplot(334)
sns.boxplot(data=data2, x=data2["drivewheel"], y=data2["price"], hue=None ,color='Orange',ax=ax)
ax.set_title('drivewheel vs price', fontsize=16)

ax=fig.add_subplot(335)
sns.boxplot(data=data2, x=data2["enginelocation"], y=data2["price"], hue=None ,color='Yellow',ax=ax)
ax.set_title('enginelocation vs price', fontsize=16)


ax=fig.add_subplot(336)
sns.boxplot(data=data2, x=data2["enginetype"], y=data2["price"], hue=None ,color='MediumSpringGreen',ax=ax)
ax.set_title('enginetype vs price', fontsize=16)

ax=fig.add_subplot(337)
sns.boxplot(data=data2, x=data2["cylindernumber"], y=data2["price"], hue=None ,color='DodgerBlue',ax=ax)
ax.set_title('cylindernumber vs price', fontsize=16)


ax=fig.add_subplot(338)
sns.boxplot(data=data2, x=data2["fuelsystem"], y=data2["price"], hue=None ,color='Peru',ax=ax)
ax.set_title('fuelsysytem vs price', fontsize=16)

ax=fig.add_subplot(339)
sns.boxplot(data=data2, x=data2["carbody"], y=data2["price"], hue=None ,color='DimGray',ax=ax)
ax.set_title('carbody vs price', fontsize=16)


plt.show()

# %% [markdown]
# # Methods To Detech Outliers

# %%
data=pd.read_csv(r"C:\Users\KAUSHIK\OneDrive\Desktop\DataScience Fullstack\CarPrice_Assignment.csv")
data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
data=pd.read_csv(r"C:\Users\KAUSHIK\OneDrive\Desktop\DataScience Fullstack\CarPrice_Assignment.csv")
data.drop('car_ID',axis=1,inplace=True)
dg=data.drop(categorical_cols, axis=1)
columns=dg.columns.to_list()
columns, dg.shape
# Out:
# (['symboling',
#   'wheelbase',
#   'carlength',
#   'carwidth',
#   'carheight',
#   'curbweight',
#   'enginesize',
#   'boreratio',
#   'stroke',
#   'compressionratio',
#   'horsepower',
#   'peakrpm',
#   'citympg',
#   'highwaympg',
#   'price'],
#  (205, 15))

# %% [markdown]
# # 1) Winsorization Method(Percentile Capping)

# %%
def Winsorization(columns, data, a, b):
    outliers=[]

    for col in columns:
        q1= np.percentile(data[col], a)
        q2= np.percentile(data[col],b)
        
        for pos in range(len(data)):
            if data[col].iloc[pos]>q2 or data[col].iloc[pos]<q1:
                outliers.append(pos) 
                
    return outliers

# %%
outliers= Winsorization(columns,dg, a=1, b=99)
outliers=set(outliers)
outliers=list(outliers)

# %% [markdown]
# # 2) Z_Score Method

# %%
def Z_Score(columns, data):
    outliers1=[]
    for col in columns:
        mean=np.mean(data[col])
        std=np.std(data[col])
        
        for pos in range(len(data)):
            item=data[col].iloc[pos]
            z_score=(item-mean)/std
            
            if np.abs(z_score)>3:
                outliers1.append(pos)
        
        return outliers1

# %%
outliers1= Z_Score(columns, dg)
outliers1=set(outliers1)
outliers1=list(outliers1)

# %% [markdown]
# # 3) IQR Method

# %%
def IQR(columns, data):
    outliers2=[]
    for col in columns:
        q1 = data[col].quantile(0.25)
        q3 = data[col].quantile(0.75)
        iqr = q3 - q1
        lower_tail= q1 - (2.5 * iqr)
        upper_tail= q3 + (2.5 * iqr)
        for pos in range(len(data)):
            if data[col].iloc[pos] > upper_tail or data[col].iloc[pos] < lower_tail:
                outliers2.append(pos)
        
                
    return outliers2

# %%
outliers2= IQR(columns,dg)
outliers2=set(outliers2)
outliers2=list(outliers2)

# %% [markdown]
# # Ratio of Outliers in dataset using Different Methods

# %%
def ratio(data, outliers):
    ratio= len(outliers)/len(data)
    return ratio

# %%
print(f"Outliers Detected by Winsorzation Method: {ratio(dg, outliers)}")
print(f"Outliers Detected by Z_Score Method: {ratio(dg, outliers1)}")
print(f"outliers Detected by IQR Method:{ratio(dg, outliers2)}")
# Out:
# Outliers Detected by Winsorzation Method: 0.16097560975609757
# Outliers Detected by Z_Score Method: 0.0
# outliers Detected by IQR Method:0.14634146341463414

# %% [markdown]
# # Removing the outliers from the dataframe Detected by Winsorization Method

# %%
data.drop(data.index[outliers], inplace=True)

# %%
data.head()
# Out:
#    symboling      CarName fueltype aspiration doornumber carbody drivewheel  \
# 3          2  audi 100 ls      gas        std       four   sedan        fwd
# 4          2   audi 100ls      gas        std       four   sedan        4wd
# 5          2     audi fox      gas        std        two   sedan        fwd
# 6          1   audi 100ls      gas        std       four   sedan        fwd
# 7          1    audi 5000      gas        std       four   wagon        fwd
#
#   enginelocation  wheelbase  carlength  ...  enginesize  fuelsystem  \
# 3          front       99.8      176.6  ...         109        mpfi
# 4          front       99.4      176.6  ...         136        mpfi
# 5          front       99.8      177.3  ...         136        mpfi
# 6          front      105.8      192.7  ...         136        mpfi
# 7          front      105.8      192.7  ...         136        mpfi
#
#    boreratio stroke compressionratio  horsepower peakrpm  citympg  highwaympg  \
# ...

# %% [markdown]
# # ALGORITHMS PREPARERATION

# %%
from xgboost import XGBRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import LinearRegression
import xgboost as xgb
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,ExtraTreesRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score

# %%
x_train, x_test, y_train, y_test=train_test_split(data.drop("price", axis=1), data["price"],test_size=0.3,random_state=42)

x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((120, 24), (120,), (52, 24), (52,))

# %% [markdown]
# # X_train Encoding

# %%
ohe= OneHotEncoder(handle_unknown="ignore")

x_train_ohe= ohe.fit_transform(x_train[categorical_cols])
x_train_ohe= x_train_ohe.toarray()

x_train_ohe_df= pd.DataFrame(x_train_ohe, columns=ohe.get_feature_names_out([categorical_cols[i]  for i in range(len(categorical_cols))]))

# One-hot encoding removed an index. Let's put it back:
x_train_ohe_df.index= x_train.index

# Joining the tables
x_train = pd.concat([x_train, x_train_ohe_df], axis=1)

# Dropping old categorical columns
x_train.drop(categorical_cols, axis=1, inplace=True)

# Checking result
x_train.head()
# Out:
#      symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 46           2       96.0      172.6      65.2       51.4        2734
# 151          1       95.7      158.7      63.6       54.5        2040
# 27           1       93.7      157.3      63.8       50.6        2191
# 169          2       98.4      176.2      65.6       52.0        2551
# 116          0      107.9      186.7      68.4       56.7        3252
#
#      enginesize  boreratio  stroke  compressionratio  ...  cylindernumber_six  \
# 46          119       3.43    3.23               9.2  ...                 0.0
# 151          92       3.05    3.03               9.0  ...                 0.0
# 27           98       3.03    3.39               7.6  ...                 0.0
# 169         146       3.62    3.50               9.3  ...                 0.0
# 116         152       3.70    3.52              21.0  ...                 0.0
#
# ...

# %% [markdown]
# # X_test Encoding

# %%
x_test_ohe= ohe.transform(x_test[categorical_cols])
x_test_ohe= x_test_ohe.toarray()

x_test_ohe_df= pd.DataFrame(x_test_ohe, columns=ohe.get_feature_names_out([categorical_cols[i] for i in range(len(categorical_cols))]))
#print(x_test_ohe_df)

# One-hot encoding removed an index. Let's put it back:
x_test_ohe_df.index= x_test.index

# Joining the tables
x_test= pd.concat([x_test, x_test_ohe_df], axis=1)

# Dropping old categorical columns
x_test.drop(categorical_cols, axis=1, inplace=True)

# Checking result
x_test.head()
# Out:
#      symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 95           1       94.5      165.6      63.8       53.3        2028
# 164          1       94.5      168.7      64.0       52.6        2204
# 180         -1      104.5      187.8      66.5       54.1        3131
# 78           2       93.7      157.3      64.4       50.8        2004
# 186          2       97.3      171.7      65.5       55.7        2275
#
#      enginesize  boreratio  stroke  compressionratio  ...  cylindernumber_six  \
# 95           97       3.15    3.29               9.4  ...                 0.0
# 164          98       3.19    3.03               9.0  ...                 0.0
# 180         171       3.27    3.35               9.2  ...                 1.0
# 78           92       2.97    3.23               9.4  ...                 0.0
# 186         109       3.19    3.40               9.0  ...                 0.0
#
# ...

# %% [markdown]
# # Linear Regression

# %%
Lr= LinearRegression()
Lr.fit(x_train, y_train)
y_pred = Lr.predict(x_test)

print (f"model : {Lr} and  rmse score is : {np.sqrt(mean_squared_error(y_test, y_pred))}, r2 score is {r2_score(y_test, y_pred)}")
# Out:
# model : LinearRegression() and  rmse score is : 4172120.7294214056, r2 score is -357300.6504739417

# %% [markdown]
# # All Models

# %%
root_mean_squared_error=[]
r2=[]
model_names=[]

# Create the Model
 
Rr = Ridge()
Lsr= Lasso() 
Rfr = RandomForestRegressor(random_state=42)
Gbr = GradientBoostingRegressor(random_state=42)
Etr= ExtraTreesRegressor(random_state=42)

models = [Rr,Lsr,Rfr,Gbr,Etr]

for model in models:
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    root_mean_squared_error.append(np.sqrt(mean_squared_error(y_test, y_pred)))
    r2.append(r2_score(y_test, y_pred))
   
    
model_names = ['Ridge','Lasso','RandomForest','GradientBoost','ExtraTree']
result_df = pd.DataFrame({'RMSE':root_mean_squared_error,'R2_score': r2},index=model_names)
result_df
# Out:
# C:\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.642e+07, tolerance: 4.622e+05
#   model = cd_fast.enet_coordinate_descent(
#                       RMSE  R2_score
# Ridge          2601.761832  0.861051
# Lasso          3174.051267  0.793201
# RandomForest   1654.554969  0.943807
# GradientBoost  1803.566521  0.933229
# ExtraTree      1894.359352  0.926338

# %%
result_df["RMSE"].plot(kind="barh", figsize=(12, 8)).legend(bbox_to_anchor=(1.0, 1.0))

# %% [markdown]
# # Feature Importance with Random Forest

# %%
x_train.shape
importances = Rfr.feature_importances_
feature_names = [f"feature {i}" for i in range(x_train.shape[1])]

for i in range(len(Rfr.feature_importances_)):
    if Rfr.feature_importances_[i] >0.01:
        print(f"{x_train.columns[i]} : {round(Rfr.feature_importances_[i],3)}")
# Out:
# wheelbase : 0.069
# carlength : 0.014
# carwidth : 0.017
# curbweight : 0.429
# enginesize : 0.2
# boreratio : 0.01
# horsepower : 0.043
# peakrpm : 0.011
# highwaympg : 0.093
# cylindernumber_four : 0.037
